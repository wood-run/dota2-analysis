# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1,3,5,np.nan,6,8])

# %%
from OpenDotaLib import PlayerInfo
test_id = 108664808 # WoodRun
snapshot = PlayerInfo.snapshot(test_id)

# %%
snapshot.keys()
# Out:
# dict_keys(['basic', 'win_lose', 'recent_matches', 'all_matches', 'heroes', 'peers', 'totals', 'counts', 'wardmap', 'ratings', 'histograms'])

# %%
snapshot['histograms']
# Out:
# {'actions_per_min':     actions_per_min  games  wins
#  0                 0      0     0
#  1                 8      0     0
#  2                16      0     0
#  3                24      0     0
#  4                32      0     0
#  5                40      0     0
#  6                48      0     0
#  7                56      0     0
#  8                64      1     0
#  9                72      0     0
#  10               80      0     0
#  11               88      1     0
#  12               96      0     0
#  13              104      1     0
#  14              112      4     1
#  15              120     19     7
#  16              128     44    14
#  17              136     60    25
#  18              144     96    49
#  19              152    120    59
#  20              160    109    59
#  21              168     93    51
#  22              176     76    50
#  23              184     72    49
#  24              192     49    42
#  25              200     28    19
# ...

# %%
list(r)
# Out:
# ['assists',
#  'cluster',
#  'deaths',
#  'duration',
#  'game_mode',
#  'gold_per_min',
#  'hero_damage',
#  'hero_healing',
#  'hero_id',
#  'is_roaming',
#  'kills',
#  'lane',
#  'lane_role',
#  'last_hits',
#  'leaver_status',
#  'lobby_type',
#  'match_id',
#  'party_size',
#  'player_slot',
#  'radiant_win',
#  'skill',
#  'start_time',
#  'tower_damage',
#  'version',
#  'xp_per_min']
